# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import *
import seaborn as sns
from matplotlib import rcParams
import datetime as dt

# %%
#!curl -O "https://s3.amazonaws.com/tripdata/2018[01-12]-citibike-tripdata.csv.zip"
#!unzip '*.zip'
#!rm *.zip
#files = !ls *.csv #For Ipython only
#df = concat([read_csv(f, header=None,low_memory=False) for f in files], keys=files)

# %%
df2 = pd.read_csv('201801-citibike-tripdata.csv')

# %%
df2.loc[df2['start station id']==3606]
# Out:
#         tripduration                 starttime                  stoptime  \
# 702154           277  2018-01-02 06:38:00.9420  2018-01-02 06:42:37.9720
# 702155          1132  2018-01-02 07:30:56.2240  2018-01-02 07:49:49.0270
# 702156           326  2018-01-02 08:12:01.4010  2018-01-02 08:17:28.0110
# 702157           203  2018-01-02 08:59:11.3530  2018-01-02 09:02:34.9560
# 702158          2135  2018-01-02 18:16:18.6640  2018-01-02 18:51:53.9840
# 702159           284  2018-01-03 08:14:19.3020  2018-01-03 08:19:03.9880
# 702160           504  2018-01-03 09:02:54.4460  2018-01-03 09:11:18.5990
# 702161          1080  2018-01-03 09:38:04.0720  2018-01-03 09:56:04.9660
# 702162           180  2018-01-03 11:50:56.5150  2018-01-03 11:53:57.4170
# 702163           559  2018-01-03 14:57:38.7210  2018-01-03 15:06:58.6550
# 702164          1476  2018-01-04 03:29:23.7980  2018-01-04 03:54:00.3420
# 702165           284  2018-01-04 08:55:12.2920  2018-01-04 08:59:56.5420
# ...

# %%
df2.keys()
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
jan_df = pd.read_csv('201801-citibike-tripdata.csv')
feb_df = pd.read_csv('201802-citibike-tripdata.csv')
mar_df = pd.read_csv('201803-citibike-tripdata.csv')
apr_df = pd.read_csv('201804-citibike-tripdata.csv')
may_df = pd.read_csv('201805-citibike-tripdata.csv')
jun_df = pd.read_csv('201806-citibike-tripdata.csv')
jul_df = pd.read_csv('201807-citibike-tripdata.csv')
aug_df = pd.read_csv('201808-citibike-tripdata.csv')
sep_df = pd.read_csv('201809-citibike-tripdata.csv')
oct_df = pd.read_csv('201810-citibike-tripdata.csv')
nov_df = pd.read_csv('201811-citibike-tripdata.csv')
dec_df = pd.read_csv('201812-citibike-tripdata.csv')

# %%
jan_count = jan_df['gender'].count()
feb_count = jan_df['gender'].count()
mar_count = jan_df['gender'].count()
apr_count = jan_df['gender'].count()
may_count = jan_df['gender'].count()
jun_count = jan_df['gender'].count()
jul_count = jan_df['gender'].count()
aug_count = jan_df['gender'].count()
sep_count = jan_df['gender'].count()
oct_count = jan_df['gender'].count()
nov_count = jan_df['gender'].count()
dec_count = jan_df['gender'].count()

# %%
jan_count + feb_count + mar_count + apr_count + may_count + jun_count + jul_count + aug_count + sep_count + oct_count + nov_count + dec_count
# Out:
# 8627928

# %%
j_gen = pd.DataFrame(jan_df['gender'].value_counts())
f_gen = pd.DataFrame(feb_df['gender'].value_counts())
m_gen = pd.DataFrame(mar_df['gender'].value_counts())
a_gen = pd.DataFrame(apr_df['gender'].value_counts())
my_gen = pd.DataFrame(may_df['gender'].value_counts())
jn_gen = pd.DataFrame(jun_df['gender'].value_counts())
jl_gen = pd.DataFrame(jul_df['gender'].value_counts())
ag_gen = pd.DataFrame(aug_df['gender'].value_counts())
s_gen = pd.DataFrame(sep_df['gender'].value_counts())
o_gen = pd.DataFrame(oct_df['gender'].value_counts())
n_gen = pd.DataFrame(nov_df['gender'].value_counts())
d_gen = pd.DataFrame(dec_df['gender'].value_counts())

# %%
total_trip_count = pd.merge(j_gen, f_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, m_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, a_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, my_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, jn_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, jl_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, ag_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, s_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, o_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, n_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count = pd.merge(total_trip_count, d_gen, how="outer", left_index=True, right_index=True)

# %%
total_trip_count
# Out:
#    gender_x  gender_y  gender
# 1   1281908    621749  702533
# 2    469544    181266  212687
# 0    201651     40099   61452

# %%
m_gen
# Out:
#    gender
# 1  702533
# 2  212687
# 0   61452

# %%
jan_locs = jan_df[["start station id", "start station latitude", "start station longitude"]]
jan_locs = jan_locs.drop_duplicates()
jan_locs.to_csv("Jan2018.csv")

# %%
feb_locs = feb_df[["start station id", "start station latitude", "start station longitude"]]
feb_locs = feb_locs.drop_duplicates()
feb_locs.to_csv("Feb2018.csv")

# %%
mar_locs = mar_df[["start station id", "start station latitude", "start station longitude"]]
mar_locs = mar_locs.drop_duplicates()
mar_locs.to_csv("Mar2018.csv")

# %%
apr_locs = apr_df[["start station id", "start station latitude", "start station longitude"]]
apr_locs = apr_locs.drop_duplicates()
apr_locs.to_csv("Apr2018.csv")

# %%
may_locs = may_df[["start station id", "start station latitude", "start station longitude"]]
may_locs = may_locs.drop_duplicates()
may_locs.to_csv("May2018.csv")

# %%
jun_locs = jun_df[["start station id", "start station latitude", "start station longitude"]]
jun_locs = jun_locs.drop_duplicates()
jun_locs.to_csv("Jun2018.csv")

# %%
jul_locs = jul_df[["start station id", "start station latitude", "start station longitude"]]
jul_locs = jul_locs.drop_duplicates()
jul_locs.to_csv("Jul2018.csv")

# %%
aug_locs = aug_df[["start station id", "start station latitude", "start station longitude"]]
aug_locs = aug_locs.drop_duplicates()
aug_locs.to_csv("Aug2018.csv")

# %%
sep_locs = sep_df[["start station id", "start station latitude", "start station longitude"]]
sep_locs = sep_locs.drop_duplicates()
sep_locs.to_csv("Sep2018.csv")

# %%
oct_locs = oct_df[["start station id", "start station latitude", "start station longitude"]]
oct_locs = oct_locs.drop_duplicates()
oct_locs.to_csv("Oct2018.csv")

# %%
nov_locs = nov_df[["start station id", "start station latitude", "start station longitude"]]
nov_locs = nov_locs.drop_duplicates()
nov_locs.to_csv("Nov2018.csv")

# %%
dec_locs = dec_df[["start station id", "start station latitude", "start station longitude"]]
dec_locs = dec_locs.drop_duplicates()
dec_locs.to_csv("Dec2018.csv")

# %%
jan_data = pd.read_csv("Jan2018.csv")
feb_data = pd.read_csv("Feb2018.csv")
mar_data = pd.read_csv("Mar2018.csv")
apr_data = pd.read_csv("Apr2018.csv")
may_data = pd.read_csv("May2018.csv")
jun_data = pd.read_csv("Jun2018.csv")
jul_data = pd.read_csv("Jul2018.csv")
aug_data = pd.read_csv("Aug2018.csv")
sep_data = pd.read_csv("Sep2018.csv")
oct_data = pd.read_csv("Oct2018.csv")
nov_data = pd.read_csv("Nov2018.csv")
dec_data = pd.read_csv("Dec2018.csv")

# %%
locs_data = pd.merge(jan_data, feb_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, mar_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, apr_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, may_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, jun_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, jul_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, aug_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, sep_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, oct_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, nov_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
locs_data = pd.merge(locs_data, dec_data, how="outer")

# %%
locs_data = locs_data.drop(["Unnamed: 0"], axis=1)
locs_data = locs_data.drop_duplicates()

# %%
bike_locs = locs_data.dropna()

# %%
bike_locs
# Out:
#      start station id  start station latitude  start station longitude
# 0                72.0               40.767272               -73.993929
# 1                79.0               40.719116               -74.006667
# 2                82.0               40.711174               -74.000165
# 3                83.0               40.683826               -73.976323
# 4               119.0               40.696089               -73.978034
# 5               120.0               40.686768               -73.959282
# 6               127.0               40.731724               -74.006744
# 7               128.0               40.727103               -74.002971
# 8               143.0               40.692395               -73.993379
# 9               144.0               40.698399               -73.980689
# 10              146.0               40.716250               -74.009106
# 11              150.0               40.720874               -73.980858
# ...

# %%
bike_locs.to_csv("bike_locs.csv")

# %%
starts = df2['start station id'].value_counts()

# %%
starts = pd.DataFrame(starts)

# %%
starts
# Out:
#       start station id
# 519               8080
# 435               5093
# 3255              4852
# 402               4526
# 497               4503
# 490               4281
# 523               4278
# 477               4256
# 285               4223
# 459               4057
# 359               3773
# 379               3652
# 293               3616
# 284               3561
# 492               3487
# 432               3454
# 3263              3351
# 229               3306
# 505               3305
# 168               3287
# 382               3181
# 504               3147
# 465               3128
# 446               3117
# 499               3112
# 368               3091
# 358               3068
# 3641              3062
# 457               3031
# 537               2941
# ...                ...
# 2005                65
# 3629                63
# 3340                63
# 3395                57
# 3525                52
# 3394                47
# 3564                45
# 3554                44
# ...

# %%
starts.keys()
# Out:
# Index(['start station id'], dtype='object')

# %%
starts = starts.reset_index()

# %%
starts = starts.rename(columns = {"index": "start station id", "start station id": "rides started"})

# %%
bike_locs = pd.merge(bike_locs, starts, how="inner", on="start station id")

# %%
bike_locs.to_csv("bike_locs.csv")

# %%
bike_locs
# Out:
#      start station id  start station latitude  start station longitude  \
# 0                72.0               40.767272               -73.993929
# 1                79.0               40.719116               -74.006667
# 2                82.0               40.711174               -74.000165
# 3                83.0               40.683826               -73.976323
# 4               119.0               40.696089               -73.978034
# 5               120.0               40.686768               -73.959282
# 6               127.0               40.731724               -74.006744
# 7               128.0               40.727103               -74.002971
# 8               143.0               40.692395               -73.993379
# 9               144.0               40.698399               -73.980689
# 10              146.0               40.716250               -74.009106
# 11              150.0               40.720874               -73.980858
# ...

# %%
jan_trips = jan_df[["tripduration"]]
feb_trips = feb_df[["tripduration"]]
mar_trips = mar_df[["tripduration"]]
apr_trips = apr_df[["tripduration"]]
may_trips = may_df[["tripduration"]]
jun_trips = jun_df[["tripduration"]]
jul_trips = jul_df[["tripduration"]]
aug_trips = aug_df[["tripduration"]]
sep_trips = sep_df[["tripduration"]]
oct_trips = oct_df[["tripduration"]]
nov_trips = nov_df[["tripduration"]]
dec_trips = dec_df[["tripduration"]]

# %%
total_trips1 = jan_trips.append(feb_trips).append(mar_trips).append(apr_trips).append(may_trips).append(jun_trips)

# %%
total_trips2 = jul_trips.append(aug_trips).append(sep_trips).append(oct_trips).append(nov_trips).append(dec_trips)

# %%
total_trips1.to_csv("total_trips1.csv")
total_trips2.to_csv("total_trips2.csv")

# %%
ride_counts = pd.DataFrame(total_trips['tripduration'].value_counts())

# %%
ride_counts.to_csv("ride_counts.csv")

# %%
ride_counts
# Out:
#          tripduration
# 319             20820
# 337             20787
# 344             20782
# 311             20779
# 341             20737
# 294             20736
# 335             20720
# 324             20715
# 329             20711
# 348             20695
# 336             20686
# 362             20669
# 300             20668
# 376             20665
# 347             20662
# 333             20656
# 298             20655
# 360             20636
# 323             20634
# 350             20630
# 331             20626
# 303             20620
# 357             20607
# 338             20555
# 326             20554
# 321             20550
# 306             20547
# 325             20543
# 363             20542
# 322             20532
# ...               ...
# 1634200             1
# 60553               1
# 76963               1
# 889415              1
# 21502               1
# 27781               1
# 54254               1
# 70614               1
# 349022              1
# ...

# %%
jan_trips.to_csv("jan_trips.csv")

# %%
jan_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
jan_df["bikeid"].value_counts()
# Out:
# 31453    222
# 31962    217
# 32105    215
# 31623    215
# 31465    215
# 33105    214
# 29984    210
# 29957    209
# 32090    207
# 33447    206
# 30315    202
# 32058    200
# 33133    200
# 33001    200
# 32340    200
# 30544    199
# 31571    199
# 32398    199
# 30203    198
# 30167    198
# 30866    198
# 32861    197
# 31550    197
# 32541    196
# 32384    196
# 32752    195
# 32588    195
# 32556    195
# 31173    195
# 32080    194
#         ...
# 21455      1
# 29858      1
# 18870      1
# 19561      1
# 16659      1
# 24336      1
# 18861      1
# 26384      1
# 28433      1
# 16978      1
# 18848      1
# 26777      1
# 27277      1
# 26898      1
# 16730      1
# 18975      1
# 20901      1
# 18571      1
# 20566      1
# 24899      1
# 21076      1
# 15892      1
# 28344      1
# 16923      1
# 18518      1
# 15292      1
# 15803      1
# 17000      1
# 19892      1
# 29031      1
# Name: bikeid, Length: 10449, dtype: int64

# %%
jan_gen = pd.DataFrame(jan_df[["tripduration","gender"]])

# %%
jan_gen.head()
# Out:
#    tripduration  gender
# 0           970       1
# 1           723       1
# 2           496       1
# 3           306       1
# 4           306       1

# %%
jan_men = jan_gen.loc[jan_gen['gender'] == 1, ['tripduration','gender']]

# %%
jan_wom = jan_gen.loc[jan_gen['gender'] == 2, ['tripduration','gender']]

# %%
jan_men.to_csv("jan_men.csv")

# %%
jan_wom.to_csv("jan_wom.csv")

# %%
jan_gen = pd.DataFrame(jan_df[["tripduration","gender"]])
feb_gen = pd.DataFrame(feb_df[["tripduration","gender"]])
mar_gen = pd.DataFrame(mar_df[["tripduration","gender"]])
apr_gen = pd.DataFrame(apr_df[["tripduration","gender"]])
may_gen = pd.DataFrame(may_df[["tripduration","gender"]])
jun_gen = pd.DataFrame(jun_df[["tripduration","gender"]])
jul_gen = pd.DataFrame(jul_df[["tripduration","gender"]])
aug_gen = pd.DataFrame(aug_df[["tripduration","gender"]])
sep_gen = pd.DataFrame(sep_df[["tripduration","gender"]])
oct_gen = pd.DataFrame(oct_df[["tripduration","gender"]])
nov_gen = pd.DataFrame(nov_df[["tripduration","gender"]])
dec_gen = pd.DataFrame(dec_df[["tripduration","gender"]])

# %%
jan_gen["month"] = "January"
feb_gen["month"] = "February"
mar_gen["month"] = "March"
apr_gen["month"] = "April"
may_gen["month"] = "May"
jun_gen["month"] = "June"
jul_gen["month"] = "July"
aug_gen["month"] = "August"
sep_gen["month"] = "September"
oct_gen["month"] = "October"
nov_gen["month"] = "November"
dec_gen["month"] = "December"

# %%
gen_df = jan_gen.append(feb_gen).append(mar_gen).append(apr_gen).append(may_gen).append(jun_gen).append(jul_gen).append(aug_gen).append(sep_gen).append(oct_gen).append(nov_gen).append(dec_gen)

# %%
gen_df = gen_df.loc[gen_df['gender'] > 0, ['tripduration','gender', 'month']]

# %%
gen_df.head()
# Out:
#    tripduration  gender    month
# 0           970       1  January
# 1           723       1  January
# 2           496       1  January
# 3           306       1  January
# 4           306       1  January

# %%
gen_df.to_csv("gen_df.csv")

# %%
gen_df["month"].value_counts()
# Out:
# August       1771797
# October      1753015
# June         1751452
# September    1704397
# July         1702825
# May          1625120
# November     1193237
# April        1184014
# December      970297
# March         915220
# February      803015
# January       689395
# Name: month, dtype: int64

# %%
gen_df["gender"].value_counts()
# Out:
# 1    11971322
# 2     4092462
# Name: gender, dtype: int64

# %%
gender_rides = pd.DataFrame(gen_df.groupby(['month', 'gender'])['tripduration'].count())

# %%
gender_rides.to_csv("gender_rides.csv")

# %%
pd.DataFrame(jan_df.groupby(['bikeid', 'start station id'])['start station id'].count())
# Out:
#                          start station id
# bikeid start station id
# 14529  249                              1
#        252                              1
#        254                              2
#        265                              1
#        268                              1
#        284                              2
#        293                              1
#        295                              2
#        297                              1
#        307                              1
#        328                              1
#        334                              1
#        335                              3
#        336                              1
#        346                              1
#        357                              1
#        363                              1
#        369                              1
#        380                              1
#        383                              1
#        401                              1
# ...

# %%
bikeid_df = pd.DataFrame(jan_df.groupby(['bikeid'])['start station id'].count())

# %%
bikeid_df.to_csv("bikeid.csv")

# %%
bikeid_df.head()
# Out:
#         start station id
# bikeid
# 14529                 69
# 14530                 56
# 14532                  7
# 14533                 17
# 14534                 83

# %%
bikeid_df_dur = pd.DataFrame(jan_df.groupby(['bikeid'])['tripduration'].mean())

# %%
bikeid_df_final = pd.merge(bikeid_df, bikeid_df_dur, how='inner', on='bikeid')

# %%
bikeid_df.nlargest(10, 'start station id')
# Out:
#         start station id
# bikeid
# 31453                222
# 31962                217
# 31465                215
# 31623                215
# 32105                215
# 33105                214
# 29984                210
# 29957                209
# 32090                207
# 33447                206

# %%
bikeid_df.count()
# Out:
# start station id    10449
# dtype: int64

# %%
bikeid_df_final.to_csv("bikeid.csv")

# %%
bikeid_df_final['tripduration'].max()
# Out:
# 4421929.0

# %%
bikeid_df_final
# Out:
#         start station id  tripduration
# bikeid
# 14529                 69    812.971014
# 14530                 56    666.964286
# 14532                  7    461.000000
# 14533                 17    413.941176
# 14534                 83    708.469880
# 14535                  2    719.500000
# 14536                 55    574.800000
# 14537                 80   1890.637500
# 14539                 82    670.878049
# 14540                 42    631.833333
# 14544                 12    620.500000
# 14545                 51    762.333333
# 14547                 72    639.958333
# 14548                  4    805.500000
# 14549                 54    707.370370
# 14550                 62    896.790323
# 14551                 93    589.053763
# 14552                  1    631.000000
# 14553                 36    646.861111
# 14555                 85    624.082353
# 14556                 64    918.828125
# 14558                 73    601.191781
# 14559                 20    492.850000
# ...

# %%
bikeid_df_final = bikeid_df_final.loc[bikeid_df_final['tripduration'] < 3600]

# %%
bikeid_df_final
# Out:
#         start station id  tripduration
# bikeid
# 14529                 69    812.971014
# 14530                 56    666.964286
# 14532                  7    461.000000
# 14533                 17    413.941176
# 14534                 83    708.469880
# 14535                  2    719.500000
# 14536                 55    574.800000
# 14539                 82    670.878049
# 14540                 42    631.833333
# 14544                 12    620.500000
# 14545                 51    762.333333
# 14547                 72    639.958333
# 14548                  4    805.500000
# 14549                 54    707.370370
# 14550                 62    896.790323
# 14551                 93    589.053763
# 14552                  1    631.000000
# 14553                 36    646.861111
# 14555                 85    624.082353
# 14556                 64    918.828125
# 14558                 73    601.191781
# 14559                 20    492.850000
# 14561                 86    667.104651
# ...
